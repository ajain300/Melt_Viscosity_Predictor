# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from validation.tests import get_Mw_samples, get_shear_samples
from sklearn.preprocessing import MinMaxScaler, PowerTransformer

# %%
Me_df = pd.read_excel('../Data/EntanglementMW.xlsx')
Me_df
# Out:
#                                    Polymer  \
# 0              Poly(bisphenol A carbonate)
# 1                    Polyetherketoneketone
# 2                         polyethersulfone
# 3                 poly(dodecano-12-lactam)
# 4                    Poly(hexano-6-lactam)
# 5                          polyisobutylene
# 6                            polypropylene
# 7                               polyethene
# 8                poly(vinylidene fluoride)
# 9                   poly(dimethylsiloxane)
# 10                 Polytetrafluoroethylene
# 11                         poly(L-lactide)
# 12          Poly (butylene terephthalate)
# 13                    poly(vinyl chloride)
# 14  Poly(tetramethylbisphenol A carbonate)
# 15              poly(1,4-butylene adipate)
# 16               Poly(methyl methacrylate)
# 17                  poly(hexano-6-lactone)
# 18                        polyethersulfone
# 19                   Poly(2-methylstyrene)
# 20                   Poly(4-methylstyrene)
# 21               poly(4-tert-butylstyrene)
# 22          Polytrimethylene terephthalate
# 23                  Poly(propylene glycol)
# 24              Poly(hexamethylene glycol)
# 25                     Poly(1-pentenylene)
# 26                poly(dodecano-12-lactam)
# 27                   Poly(hexano-6-lactam)
# 28                 Poly(p-phenylene oxide)
# 29    Poly(2,6-diphenyl-p-phenylene oxide)
# 30                  Poly(ethylene sulfide)
# 31                     poly(vinyl acetate)
# 32                     Poly(vinyl formate)
# 33            Poly(ethylene terephthalate)
# 34                         Polyoxyethylene
# 35                    Poly(vinyl fluoride)
# 36              Poly(epsilon-caprolactone)
# 37                     Poly(glycolic acid)
# 38                     Poly(vinyl alcohol)
# 39                 Polytetrafluoroethylene
# 40                      Poly(acrylic acid)
# 41                  Poly(methacrylic acid)
# 42                          Polyacrylamide
# 43               Poly(vinylidene chloride)
# 44             Poly(ethyl 2-cyanoacrylate)
# 45                       Polyacrylonitrile
# 46                    Poly(vinyl butyrate)
# 47                Poly(ethyl methacrylate)
# 48                             Polystyrene
# 49                        Polyoxymethylene
# 50                   Poly(propylene oxide)
# 51                           polybutadiene
# 52                            polyisoprene
#
#                                                SMILES     Me  \
# 0            [*]Oc1ccc(C(C)(C)c2ccc(OC([*])=O)cc2)cc1   2600
# 1     [*]Oc1ccc(C(=O)c2ccc(C(=O)c3ccc([*])cc3)cc2)cc1   1700
# 2                [*]Oc1ccc(S(=O)(=O)c2ccc([*])cc2)cc1   3850
# 3                             [*]CCCCCCCCCCCC(=O)N[*]   1950
# 4                                   [*]CCCCCC(=O)N[*]   2500
# 5                                      [*]CC([*])(C)C   7950
# 6                                         [*]CC([*])C   4650
# 7                                             [*]C[*]   1150
# 8                                      [*]CC([*])(F)F   2600
# 9                                   [*]O[Si]([*])(C)C   9325
# 10                                      [*]C([*])(F)F   4650
# 11                                   [*]OC(C)C([*])=O   8700
# 12                   [*]CCCCOC(=O)c1ccc(C(=O)O[*])cc1   1600
# 13                                       [*]CC([*])Cl   5750
# 14  [*]Oc1c(C)cc(C(C)(C)c2cc(C)c(OC([*])=O)c(C)c2)...   3420
# 15                         [*]CCCCOC(=O)CCCCC(=O)O[*]   2050
# 16                               [*]CC([*])(C)C(=O)OC  10200
# 17                                  [*]CCCCCC(=O)O[*]   2400
# 18               [*]Oc1ccc(S(=O)(=O)c2ccc([*])cc2)cc1   3850
# 19                                [*]CC([*])c1ccccc1C  19000
# 20                              [*]CC([*])c1ccc(C)cc1  25000
# 21                       [*]CC([*])c1ccc(C(C)(C)C)cc1  22000
# 22                    [*]CCCOC(=O)c1ccc(C(=O)O[*])cc1   1650
# 23                                       [*]CC(C)O[*]   2800
# 24                                      [*]CCCCCCO[*]   1800
# 25                                       [*]C=CCCC[*]   1400
# 26                            [*]CCCCCCCCCCCC(=O)N[*]   1950
# 27                                  [*]CCCCCC(=O)N[*]   2500
# 28                                  [*]Oc1ccc([*])cc1   2560
# 29              [*]Oc1c(-c2ccccc2)cc([*])cc1-c1ccccc1  12000
# 30                                          [*]CCS[*]   3750
# 31                                  [*]CC([*])OC(C)=O   7700
# 32                                     [*]CC([*])OC=O   4450
# 33                     [*]CCOC(=O)c1ccc(C(=O)O[*])cc1   1700
# 34                                          [*]CCO[*]   2100
# 35                                        [*]CC([*])F   1650
# 36                                  [*]CCCCCC(=O)O[*]   2400
# 37                                      [*]CC(=O)O[*]   3400
# 38                                        [*]CC([*])O   5250
# 39                                      [*]C([*])(F)F   5400
# 40                                   [*]CC([*])C(=O)O   6900
# 41                                [*]CC([*])(C)C(=O)O   7550
# 42                                   [*]CC([*])C(N)=O  14000
# 43                                   [*]CC([*])(Cl)Cl  14600
# 44                            [*]CC([*])(C#N)C(=O)OCC  29500
# 45                                      [*]CC([*])C#N   7900
# 46                                [*]CC([*])OC(=O)CCC  13800
# 47                              [*]CC([*])(C)C(=O)OCC  13500
# 48                                 [*]CC([*])c1ccccc1  15500
# 49                                           [*]CO[*]   2900
# 50                                       [*]CC(C)O[*]   2800
# 51                                        [*]C=CCC[*]   1850
# 52                                                NaN   6400
#
#                                            Unnamed: 3
# 0                                    Polymer Database
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33  Mc from L-M theory | Practical Rheology Scienc...
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
# 51                                                NaN
# 52                                   Rubenstein et al

# %%
data = pd.read_excel('Data/full_data_2022-03-08.xlsx', na_values = ['nan','','NaN'])
data.columns = [str(c) for c in data.columns]

OG_fp = []
for c in data.columns:
    if isinstance(c, str):
        if 'fp' in c:
            OG_fp.append(c)
len(OG_fp)

do_pca = False
if do_pca:
    data, fp_cols, pca = fp_PCA(data, 17, cols = OG_fp)
    cols = fp_cols + ['Mw', 'Temperature', 'Shear_Rate','Melt_Viscosity']
else:
    fp_cols = OG_fp
    cols = fp_cols + ['Mw', 'Temperature', 'Shear_Rate','Melt_Viscosity']

# for c in ['Mw', 'Melt_Viscosity']:
#     data[c] = np.log10(data[c])

data['PDI'].fillna(2)
data['ZERO_SHEAR'] = 1
data['SHEAR'] = 0
data['log_Shear_Rate'] = 0
for i in data.index:
    if data.loc[i, 'Shear_Rate'] != 0:
        data.loc[i, 'SHEAR'] = 1
        data.loc[i, 'ZERO_SHEAR'] = 0
    if not data.loc[i,'PDI'] > 0:
        data.loc[i,'PDI'] = 2
    if data.loc[i,'PDI'] > 100:
        data.loc[i,'PDI'] = 2
        #data = data.drop([i])
train_df = data.copy()
train_df['Aug'] = 0

# %%
# logMw = np.array(train_df['Mw']).reshape((-1,1))
# shear = np.array(train_df['Shear_Rate']).reshape((-1,1))
# Temp = np.array(train_df['Temperature']).reshape((-1,1))
# Temp = 1/(Temp+273.15)
# PDI = np.array(train_df['PDI']).reshape((-1,1))

# scaler = MinMaxScaler(copy = False)
# XX = np.array(scaler.fit(train_df.filter(fp_cols)).transform(train_df.filter(fp_cols)))
# yy = np.array(train_df.loc[:,'Melt_Viscosity']).reshape((-1,1))

# y_scaler = MinMaxScaler().fit(yy)
# yy = y_scaler.transform(yy);
# T_scaler = MinMaxScaler().fit(Temp)
# T = T_scaler.transform(Temp);
# M_scaler = MinMaxScaler().fit(logMw)
# M = M_scaler.transform(logMw);
# S_trans = PowerTransformer(standardize = False).fit(shear)
# S_scaler = MinMaxScaler().fit(S_trans.transform(shear))
# S = S_scaler.transform(S_trans.transform(shear))
# P_scaler = MinMaxScaler().fit(PDI)
# P = P_scaler.transform(PDI)

# %%
Mw_samps, mw_ids = get_Mw_samples(train_df.copy().sort_index());
shear_samps, shear_ids = get_shear_samples(train_df.copy().sort_index())

# %%
samp_num = 40
samp = Mw_samps.loc[Mw_samps['SAMPLE_ID'] == mw_ids[samp_num], :].reset_index()
Mw = np.array(samp['Mw']).reshape(-1,1)[~np.isnan(samp['Melt_Viscosity'])]
visc = np.array(samp['Melt_Viscosity']).reshape(-1,1)[~np.isnan(samp['Melt_Viscosity'])]
smiles = samp['SMILES'][0]
plt.scatter(Mw, visc, label = 'Experimental Data')
m, b = np.polyfit(Mw.reshape(-1,)[0:], visc.reshape(-1,)[0:], 1)
Mcr = np.log10(np.array(Me_df.loc[Me_df['SMILES'] == smiles, 'Me'])[0]*2)
Mcr_y = Mcr*m + b
print(m)
low_Mw = np.linspace(3, Mcr, min(5, samp.shape[0])).reshape(-1,1)
visc_low_Mw = (low_Mw-Mcr) + Mcr_y
plt.scatter(low_Mw, visc_low_Mw, label = 'Augmented Data')
plt.scatter(Mcr, Mcr_y, label = 'Mcr')
plt.title(samp.loc[0,'Polymer'])
plt.ylabel(r'Log $\eta_o$')
plt.xlabel('LogMw')
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/ayush/Melt_Viscosity_Predictor/low_Mw_augmentation.ipynb Cell 6' in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2Btyrion2/home/ayush/Melt_Viscosity_Predictor/low_Mw_augmentation.ipynb#ch0000004vscode-remote?line=0'>1</a> samp_num = 40
# ----> <a href='vscode-notebook-cell://ssh-remote%2Btyrion2/home/ayush/Melt_Viscosity_Predictor/low_Mw_augmentation.ipynb#ch0000004vscode-remote?line=1'>2</a> samp = Mw_samps.loc[Mw_samps['SAMPLE_ID'] == mw_ids[samp_num], :].reset_index()
#       <a href='vscode-notebook-cell://ssh-remote%2Btyrion2/home/ayush/Melt_Viscosity_Predictor/low_Mw_augmentation.ipynb#ch0000004vscode-remote?line=2'>3</a> Mw = np.array(samp['Mw']).reshape(-1,1)[~np.isnan(samp['Melt_Viscosity'])]
#       <a href='vscode-notebook-cell://ssh-remote%2Btyrion2/home/ayush/Melt_Viscosity_Predictor/low_Mw_augmentation.ipynb#ch0000004vscode-remote?line=3'>4</a> visc = np.array(samp['Melt_Viscosity']).reshape(-1,1)[~np.isnan(samp['Melt_Viscosity'])]
#
# IndexError: list index out of range

# %%
add = Mw_samps.loc[Mw_samps['SAMPLE_ID'] == mw_ids[samp_num], :].reset_index().loc[:min(5, samp.shape[0]) -1]
add['Melt_Viscosity'] = np.power(10,visc_low_Mw)
add['Mw'] = np.power(10, low_Mw)
add['PDI'] = np.mean(np.array(Mw_samps.loc[Mw_samps['SAMPLE_ID'] == mw_ids[samp_num], 'PDI']))
add['Mn'] = np.nan
add['Aug'] = 1
add = add.drop(columns=['index'])
add.head()
# Out:
#    INDEX  SAMPLE_ID              SMILES      Polymer  Mn            Mw  PDI  \
# 0   1156     1190.0  [*]CC([*])c1ccccc1  polystyrene NaN   1000.000000  2.0
# 1   1157     1190.0  [*]CC([*])c1ccccc1  polystyrene NaN   2359.611062  2.0
# 2   1158     1190.0  [*]CC([*])c1ccccc1  polystyrene NaN   5567.764363  2.0
# 3   1159     1190.0  [*]CC([*])c1ccccc1  polystyrene NaN  13137.758380  2.0
# 4   1160     1190.0  [*]CC([*])c1ccccc1  polystyrene NaN  31000.000000  2.0
#
#    PDI (zw)  Temperature  Shear_Rate  ...  PID 2 coPID Weight 1 Weight 2  \
# 0       NaN        190.0         0.0  ...    NaN   NaN      NaN      NaN
# 1       NaN        190.0         0.0  ...    NaN   NaN      NaN      NaN
# 2       NaN        190.0         0.0  ...    NaN   NaN      NaN      NaN
# 3       NaN        190.0         0.0  ...    NaN   NaN      NaN      NaN
# 4       NaN        190.0         0.0  ...    NaN   NaN      NaN      NaN
#
#    Frequency INDEX.1  ZERO_SHEAR  SHEAR  log_Shear_Rate  Aug
# 0        NaN     NaN           1      0               0    1
# 1        NaN     NaN           1      0               0    1
# 2        NaN     NaN           1      0               0    1
# 3        NaN     NaN           1      0               0    1
# 4        NaN     NaN           1      0               0    1
#
# [5 rows x 256 columns]

# %%
index = np.array(Mw_samps.loc[Mw_samps['SAMPLE_ID'] == mw_ids[samp_num],'INDEX'])[-1]
print(index)
train_df = InsertSamps(train_df, add, index)
# Out:
# 1167

# %%
def InsertSamps(df, samps, index):
    n = samps.shape[0]
    before = df.loc[df["INDEX"] < index + 1, :]
    after = df.loc[df["INDEX"] > index + 1, :]
    after.index = [x.__add__(n) for x in after.index]
    added = pd.concat([before, samps, after])
    return added

# %%
train_df.to_excel('Data/full_data_03_08_aug.xlsx')
